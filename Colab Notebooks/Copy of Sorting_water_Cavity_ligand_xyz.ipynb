# %%
# !pip install mdtraj
import mdtraj as md

import pickle
import numpy as np
# Out:
# Requirement already satisfied: mdtraj in /usr/local/lib/python3.7/dist-packages (1.9.5)
# Requirement already satisfied: numpy>=1.6 in /usr/local/lib/python3.7/dist-packages (from mdtraj) (1.19.5)
# Requirement already satisfied: scipy in /usr/local/lib/python3.7/dist-packages (from mdtraj) (1.4.1)
# Requirement already satisfied: astunparse in /usr/local/lib/python3.7/dist-packages (from mdtraj) (1.6.3)
# Requirement already satisfied: pyparsing in /usr/local/lib/python3.7/dist-packages (from mdtraj) (2.4.7)
# Requirement already satisfied: six<2.0,>=1.6.1 in /usr/local/lib/python3.7/dist-packages (from astunparse->mdtraj) (1.15.0)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.7/dist-packages (from astunparse->mdtraj) (0.36.2)

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
cd /content/drive/MyDrive/1780_to_4047_files
# Out:
# /content/drive/MyDrive/1780_to_4047_files

# %%
traj = pickle.load(open('traj0.pkl','rb'))

# %%
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-15-d396dd880e74> in <module>()
# ----> 1 traj = np.array(traj)
#
# /usr/local/lib/python3.7/dist-packages/mdtraj/core/trajectory.py in __getitem__(self, key)
#    1109     def __getitem__(self, key):
#    1110         "Get a slice of this trajectory"
# -> 1111         return self.slice(key)
#    1112
#    1113     def slice(self, key, copy=True):
#
# /usr/local/lib/python3.7/dist-packages/mdtraj/core/trajectory.py in slice(self, key, copy)
#    1141             xyz = xyz.copy()
#    1142             time = time.copy()
# -> 1143             topology = deepcopy(self._topology)
#    1144
#    1145             if self.unitcell_angles is not None:
#
# /usr/lib/python3.7/copy.py in deepcopy(x, memo, _nil)
#     159             copier = getattr(x, "__deepcopy__", None)
#     160             if copier:
# --> 161                 y = copier(memo)
#     162             else:
#     163                 reductor = dispatch_table.get(cls)
#
# /usr/local/lib/python3.7/dist-packages/mdtraj/core/topology.py in __deepcopy__(self, *args)
#     248
#     249     def __deepcopy__(self, *args):
# --> 250         return self.copy()
#     251
#     252     def __hash__(self):
#
# /usr/local/lib/python3.7/dist-packages/mdtraj/core/topology.py in copy(self)
#     236                 r = out.add_residue(residue.name, c, residue.resSeq, residue.segment_id)
#     237                 for atom in residue.atoms:
# --> 238                     out.add_atom(atom.name, atom.element, r, serial=atom.serial)
#     239
#     240         for bond in self.bonds:
#
# KeyboardInterrupt:

# %%
import glob

# %%
files = sorted(glob.glob('traj*.pkl'))

# %%
files
# Out:
# ['traj0.pkl',
#  'traj1.pkl',
#  'traj10.pkl',
#  'traj11.pkl',
#  'traj12.pkl',
#  'traj13.pkl',
#  'traj2.pkl',
#  'traj3.pkl',
#  'traj4.pkl',
#  'traj5.pkl',
#  'traj6.pkl',
#  'traj7.pkl',
#  'traj8.pkl',
#  'traj9.pkl']

# %%
trajs = []
for f in files:
  trajs.append(pickle.load(open(f,'rb')))

# %% [markdown]
# ## Load the discrete trajectories from drive

# %%
ls 4047.xtc
# Out:
# 4047.xtc

# %%
import gc
gc.collect()
# Out:
# 518

# %%
4047-1780
# Out:
# 2267

# %%
2267/103
# Out:
# 22.009708737864077

# %%
#  trajs = []
#  for i in range(1780,4048):
#      traj = md.load('{}.xtc'.format(i),top='{}.gro'.format(i))
#      #trajs = np.append(trajs,traj)
#      trajs.append(traj)
#      del traj
#      gc.collect()

# %%
 
 for i in range(103):
     trajs = []; x = 22 ;
     for j in range(1780+i*x,1785+(i+1)*x):
          traj = md.load('{}.xtc'.format(j),top='{}.gro'.format(j))
          #trajs = np.append(trajs,np.array(traj))
          trajs.append(traj)
          del traj
          gc.collect()
     pickle.dump(trajs,open('traj'+str(i)+'.pkl','wb'))
     del trajs
     gc.collect()

# %%
A = np.empty([])

# %%
# for i in range(1780,1785):
#      traj = md.load('{}.xtc'.format(i),top='{}.gro'.format(i))

# %%
pickle.dump(trajs,open('traj_1780_to_4047.pkl','wb'))

# %%
traj = pickle.load(open('traj_1780_to_1800.pkl','rb'))

# %%
print(traj[1][10])

# %%
#traj[1].save_xtc('first_10_frames.dcd')

# %%
topology = traj[1].topology

# %%
topology.atom(4)

# %%
topology

# %%
topology.residue(5)

# %%
print('All atom %s' % [atom for atom in topology.atoms])

# %% [markdown]
# **Get the cavity atom distances**

# %%
# hcp_atom_index = []
# for atom in topology.atoms:
#     if (atom.name=='CP'):
#         hcp_atom_index.append(atom.index)

# %%
# import numpy as np
# hcp_atom_index = np.array(hcp_atom_index)
# np.save('hcp_atom_index.npy',hcp_atom_index)

hcp_atom_index = np.load('hcp_atom_index.npy')

# %% [markdown]
# **Get the fullerene atom indexes**

# %%
# fullerene_atom_index = []
# for atom in topology.atoms:
#     if (atom.name=='CF'):
#         fullerene_atom_index.append(atom.index)

# fullerene_atom_index = np.array(fullerene_atom_index)
# np.save('fullerene_atom_index.npy',fullerene_atom_index)    

fullerene_atom_index = np.load('fullerene_atom_index.npy')

# %% [markdown]
# **Get the water atom indexes**

# %%
# water_atom_index = []
# for atom in topology.atoms:
#     if (atom.element.symbol =='O'):
#         water_atom_index.append(atom.index)

# water_atom_index = np.array(water_atom_index)
# np.save('water_atom_index.npy',water_atom_index)    

water_atom_index = np.load('water_atom_index.npy')

# %%
#A = traj[1].xyz[1][fullerene_atom_index][:]

# %%
#A[:,1]

# %%
fullerene_atom_index.shape

# %%
hcp_atom_index.shape

# %%
xyz_water = traj[1].xyz[1][water_atom_index][:]

# %%
xyz_water.shape

# %%
atom_pair = np.vstack((water_atom_index,np.ones_like(water_atom_index)*8570)).T

# %%
distance= md.compute_distances(traj[1],atom_pairs=atom_pair)

# %%
atom_pair.ndim

# %%
dist = np.sort(distance)

# %%
dist1 = dist[:,:200]

# %%
dist1.shape

# %%
np.where(distance == 0.32251507)

# %%
dist1[1,1]

# %%
temp = np.empty_like(dist1)
for i in range(len(dist1[0])):
    temp[0,i]=np.where(dist1[0,i]==distance[0,:])[0]

# %%
temp[0].shape

# %%
xyz_sorted_water=traj[0].xyz[1][temp[0].astype(int)][:]

# %%
xyz_sorted_water.shape

# %%
for i in range(len(dist1[0])):
    print(i)

# %%
index_water_sorted = np.empty_like(dist1)
for i in range(len(dist1)):
    for j in range(len(dist1)):
         index_water_sorted[i,j] = np.where(dist1[i,j]==distance[i,:])[0] 
         #print(np.where(dist1[i,j]==distance[i,:])[0])
         break

# %%
index_water_sorted.shape

# %%
traj[1].xyz[1][int(index_water_sorted[:,0])]

# %%
index_water_sorted.shape

# %%
index_water_sorted[0,:]
