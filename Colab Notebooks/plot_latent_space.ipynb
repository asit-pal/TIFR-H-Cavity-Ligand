# %%
import torch
import numpy as np
import matplotlib.pyplot as plt

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
latent = torch.load('/content/drive/MyDrive/1780_to_4047_files/model_state_dict/encoded_latent_4D.pt')

# %%
lat = latent.numpy()

# %%
torch.min(latent,dim=0)
# Out:
# torch.return_types.min(values=tensor([-3.9624e-08, -1.0283e-05, -1.5876e-05, -1.5294e-07]), indices=tensor([0, 0, 0, 0]))

# %%
fig,ax = plt.subplots(1,1)
ax.plot(lat[:,3]*1e8)
